# %%
# !pip install -qU crewai google-search-results
# Out:
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.5/42.5 kB 3.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 5.0 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.2/48.2 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.9/211.9 kB 10.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 131.8/131.8 kB 8.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 606.2/606.2 kB 28.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.4/2.4 MB 51.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.4/71.4 kB 4.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 59.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.8/55.8 kB 2.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.5/59.5 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 64.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 756.0/756.0 kB 34.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 61.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 278.6/278.6 kB 20.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 94.8/94.8 kB 6.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.4/76.4 kB 5.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 53.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.2/93.2 kB 7.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.3/13.3 MB 54.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.9/54.9 kB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 56.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 43.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.3/62.3 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.1/442.1 kB 24.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 43.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.7/319.7 kB 18.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.2/73.2 kB 5.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 78.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.9/452.9 kB 28.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 6.6 MB/s eta 0:00:00
#   Building wheel for google-search-results (setup.py) ... done
#   Building wheel for pypika (pyproject.toml) ... done
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow 2.17.1 requires protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3, but you have protobuf 5.29.3 which is incompatible.
# tensorflow-metadata 1.13.1 requires protobuf<5,>=3.20.3, but you have protobuf 5.29.3 which is incompatible.

# %% [markdown]
# API key for Google Search: https://serper.dev/

# %%
import os
from google.colab import userdata

os.environ["OPENAI_API_KEY"] = ' '
os.environ["GROQ_API_KEY"] = ' '
os.environ["SERPER_API_KEY"] = ' '

# %%
from crewai import Agent, Task, Crew, Process

product_manager = Agent(
    role='Product Manager',
    goal='Define requirements for a software product',
    backstory="You are an experienced Product Manager skilled in defining clear and concise requirements.",
    llm="groq/llama-3.3-70b-versatile",
    verbose=True,
)

coder = Agent(
    role='Software Developer',
    goal='Develop software based on the provided requirements in Python',
    backstory="You are a skilled software developer proficient in coding robust and efficient applications.",
    llm="groq/llama-3.3-70b-versatile",
    verbose=True,
)

task1 = Task(
    description="Define the key requirements and features for a classic ping pong game. Be specific and concise.",
    expected_output="A clear and concise list of requirements for the ping pong game",
    agent=product_manager,
)

task2 = Task(
    description="Based on the provided requirements, develop the code for the classic ping pong game. Focus on gameplay mechanics and a simple user interface.",
    expected_output="Complete code for the ping pong game",
    agent=coder,
)

# Instantiate your crew with a sequential process
crew = Crew(
    agents=[product_manager, coder],
    tasks=[task1, task2],
    verbose=True,
)

# Get your crew to work!
result = crew.kickoff()
print("######################")
print(result)
# Out:
# WARNING:opentelemetry.trace:Overriding of current TracerProvider is not allowed
# # Agent: Product Manager
# ## Task: Define the key requirements and features for a classic ping pong game. Be specific and concise.
#
#
# # Agent: Product Manager
# ## Final Answer:
# **Game Overview**
# The classic ping pong game is a two-dimensional sports game where two players hit a ball back and forth on a rectangular court. The game requires a set of specific features and requirements to ensure a engaging and challenging experience for players.
#
# **Core Requirements**
#
# 1. **Gameplay**: The game should allow two players to play against each other, with the option to play against the computer or in multiplayer mode.
# 2. **Court**: The game court should be rectangular, with a net in the middle, and marked with lines to indicate the playing area.
# 3. **Ball**: The ball should bounce realistically, with a speed and trajectory that simulates a real ping pong ball.
# 4. **Paddles**: Each player should have a paddle that can be controlled to hit the ball, with the option to adjust the paddle's size, speed, and responsiveness.
# 5. **Scoring**: The game should keep track of the score, with points awarded when a player fails to return the ball or hits it out of bounds.
#
# **Gameplay Features**
#
# 1. **Serving**: The game should allow players to serve the ball, with the option to adjust the serve's speed, spin, and direction.
# 2. **Rallies**: The game should allow for extended rallies, with the ball bouncing back and forth between players.
# 3. **Smashing**: The game should allow players to smash the ball, with a increased speed and power.
# 4. **Lobbing**: The game should allow players to lob the ball, with a high arc and slow speed.
# 5. **Spin**: The game should allow players to apply spin to the ball, with options for topspin, backspin, and sidespin.
#
# **User Interface**
#
# 1. **Menu System**: The game should have a menu system that allows players to select game modes, adjust settings, and view high scores.
# 2. **Gameplay Controls**: The game should have intuitive and responsive controls, with options for keyboard, mouse, and gamepad input.
# 3. **Sound Effects**: The game should have realistic sound effects, with sounds for the ball bouncing, paddles hitting, and crowd cheering.
# 4. **Graphics**: The game should have simple and clean graphics, with options for 2D and 3D modes.
#
# **Game Modes**
#
# 1. **Single Player**: The game should have a single-player mode, with the option to play against the computer or in a tournament mode.
# 2. **Multiplayer**: The game should have a multiplayer mode, with options for online and local multiplayer.
# 3. **Training Mode**: The game should have a training mode, with options for practicing serves, rallies, and other skills.
#
# **Settings**
#
# 1. **Difficulty Level**: The game should have adjustable difficulty levels, with options for beginner, intermediate, and advanced players.
# 2. **Ball Speed**: The game should have adjustable ball speed, with options for slow, medium, and fast speeds.
# 3. **Paddle Size**: The game should have adjustable paddle size, with options for small, medium, and large paddles.
#
# By incorporating these features and requirements, the classic ping pong game will provide an engaging and challenging experience for players of all skill levels.
#
#
# # Agent: Software Developer
# ## Task: Based on the provided requirements, develop the code for the classic ping pong game. Focus on gameplay mechanics and a simple user interface.
#
#
# # Agent: Software Developer
# ## Final Answer:
# ```python
# import pygame
# import sys
#
# # Initialize Pygame
# pygame.init()
#
# # Set up some constants
# WIDTH, HEIGHT = 800, 600
# BALL_RADIUS = 20
# PADDLE_WIDTH = 10
# PADDLE_HEIGHT = 100
# FPS = 60
#
# # Set up some colors
# WHITE = (255, 255, 255)
# BLACK = (0, 0, 0)
#
# # Set up the display
# SCREEN = pygame.display.set_mode((WIDTH, HEIGHT))
# pygame.display.set_caption("Ping Pong")
#
# # Set up the font
# FONT = pygame.font.Font(None, 36)
#
# # Set up the clock
# CLOCK = pygame.time.Clock()
#
# class Ball:
#     def __init__(self):
#         self.x = WIDTH / 2
#         self.y = HEIGHT / 2
#         self.vx = 5
#         self.vy = 5
#         self.speed = 5
#
#     def update(self):
#         self.x += self.vx
#         self.y += self.vy
#
#         if self.y < 0 or self.y > HEIGHT:
#             self.vy *= -1
#
#     def reset(self):
#         self.x = WIDTH / 2
#         self.y = HEIGHT / 2
#         self.vx = 5
#         self.vy = 5
#
# class Paddle:
#     def __init__(self, x, y):
#         self.x = x
#         self.y = y
#         self.speed = 5
#
#     def update(self, direction):
#         if direction == "up" and self.y > 0:
#             self.y -= self.speed
#         elif direction == "down" and self.y < HEIGHT - PADDLE_HEIGHT:
#             self.y += self.speed
#
# def draw_text(text, x, y):
#     text_surface = FONT.render(text, True, WHITE)
#     SCREEN.blit(text_surface, (x, y))
#
# def main():
#     ball = Ball()
#     paddle1 = Paddle(10, HEIGHT / 2 - PADDLE_HEIGHT / 2)
#     paddle2 = Paddle(WIDTH - 20, HEIGHT / 2 - PADDLE_HEIGHT / 2)
#     score1 = 0
#     score2 = 0
#
#     while True:
#         for event in pygame.event.get():
#             if event.type == pygame.QUIT:
#                 pygame.quit()
#                 sys.exit()
#
#         keys = pygame.key.get_pressed()
#         if keys[pygame.K_w]:
#             paddle1.update("up")
#         if keys[pygame.K_s]:
#             paddle1.update("down")
#         if keys[pygame.K_UP]:
#             paddle2.update("up")
#         if keys[pygame.K_DOWN]:
#             paddle2.update("down")
#
#         ball.update()
#
#         if ball.x < 0:
#             score2 += 1
#             ball.reset()
#         elif ball.x > WIDTH:
#             score1 += 1
#             ball.reset()
#
#         if (ball.x < PADDLE_WIDTH and
#             ball.y > paddle1.y and
#             ball.y < paddle1.y + PADDLE_HEIGHT):
#             ball.vx *= -1
#         elif (ball.x > WIDTH - PADDLE_WIDTH - BALL_RADIUS and
#               ball.y > paddle2.y and
#               ball.y < paddle2.y + PADDLE_HEIGHT):
#             ball.vx *= -1
#
#         SCREEN.fill(BLACK)
#         pygame.draw.rect(SCREEN, WHITE, (paddle1.x, paddle1.y, PADDLE_WIDTH, PADDLE_HEIGHT))
#         pygame.draw.rect(SCREEN, WHITE, (paddle2.x, paddle2.y, PADDLE_WIDTH, PADDLE_HEIGHT))
#         pygame.draw.circle(SCREEN, WHITE, (int(ball.x), int(ball.y)), BALL_RADIUS)
#         pygame.draw.aaline(SCREEN, WHITE, (WIDTH / 2, 0), (WIDTH / 2, HEIGHT))
#         draw_text(str(score1), WIDTH / 2 - 50, 20)
#         draw_text(str(score2), WIDTH / 2 + 30, 20)
#
#         pygame.display.flip()
#         CLOCK.tick(FPS)
#
# if __name__ == "__main__":
#     main()
# ```
# This code implements a basic version of the classic Ping Pong game using Pygame. It includes a ball that bounces around the screen, two paddles that can be controlled by the player, and a scoring system. The game can be played by two players using the W and S keys for the left paddle and the UP and DOWN keys for the right paddle.
#
#
# ######################
# ```python
# import pygame
# import sys
#
# # Initialize Pygame
# pygame.init()
#
# # Set up some constants
# WIDTH, HEIGHT = 800, 600
# BALL_RADIUS = 20
# PADDLE_WIDTH = 10
# PADDLE_HEIGHT = 100
# FPS = 60
#
# # Set up some colors
# WHITE = (255, 255, 255)
# BLACK = (0, 0, 0)
#
# # Set up the display
# SCREEN = pygame.display.set_mode((WIDTH, HEIGHT))
# pygame.display.set_caption("Ping Pong")
#
# # Set up the font
# FONT = pygame.font.Font(None, 36)
#
# # Set up the clock
# CLOCK = pygame.time.Clock()
#
# class Ball:
#     def __init__(self):
#         self.x = WIDTH / 2
#         self.y = HEIGHT / 2
#         self.vx = 5
#         self.vy = 5
#         self.speed = 5
#
#     def update(self):
#         self.x += self.vx
#         self.y += self.vy
#
#         if self.y < 0 or self.y > HEIGHT:
#             self.vy *= -1
#
#     def reset(self):
#         self.x = WIDTH / 2
#         self.y = HEIGHT / 2
#         self.vx = 5
#         self.vy = 5
#
# class Paddle:
#     def __init__(self, x, y):
#         self.x = x
#         self.y = y
#         self.speed = 5
#
#     def update(self, direction):
#         if direction == "up" and self.y > 0:
#             self.y -= self.speed
#         elif direction == "down" and self.y < HEIGHT - PADDLE_HEIGHT:
#             self.y += self.speed
#
# def draw_text(text, x, y):
#     text_surface = FONT.render(text, True, WHITE)
#     SCREEN.blit(text_surface, (x, y))
#
# def main():
#     ball = Ball()
#     paddle1 = Paddle(10, HEIGHT / 2 - PADDLE_HEIGHT / 2)
#     paddle2 = Paddle(WIDTH - 20, HEIGHT / 2 - PADDLE_HEIGHT / 2)
#     score1 = 0
#     score2 = 0
#
#     while True:
#         for event in pygame.event.get():
#             if event.type == pygame.QUIT:
#                 pygame.quit()
#                 sys.exit()
#
#         keys = pygame.key.get_pressed()
#         if keys[pygame.K_w]:
#             paddle1.update("up")
#         if keys[pygame.K_s]:
#             paddle1.update("down")
#         if keys[pygame.K_UP]:
#             paddle2.update("up")
#         if keys[pygame.K_DOWN]:
#             paddle2.update("down")
#
#         ball.update()
#
#         if ball.x < 0:
#             score2 += 1
#             ball.reset()
#         elif ball.x > WIDTH:
#             score1 += 1
#             ball.reset()
#
#         if (ball.x < PADDLE_WIDTH and
#             ball.y > paddle1.y and
#             ball.y < paddle1.y + PADDLE_HEIGHT):
#             ball.vx *= -1
#         elif (ball.x > WIDTH - PADDLE_WIDTH - BALL_RADIUS and
#               ball.y > paddle2.y and
#               ball.y < paddle2.y + PADDLE_HEIGHT):
#             ball.vx *= -1
#
#         SCREEN.fill(BLACK)
#         pygame.draw.rect(SCREEN, WHITE, (paddle1.x, paddle1.y, PADDLE_WIDTH, PADDLE_HEIGHT))
#         pygame.draw.rect(SCREEN, WHITE, (paddle2.x, paddle2.y, PADDLE_WIDTH, PADDLE_HEIGHT))
#         pygame.draw.circle(SCREEN, WHITE, (int(ball.x), int(ball.y)), BALL_RADIUS)
#         pygame.draw.aaline(SCREEN, WHITE, (WIDTH / 2, 0), (WIDTH / 2, HEIGHT))
#         draw_text(str(score1), WIDTH / 2 - 50, 20)
#         draw_text(str(score2), WIDTH / 2 + 30, 20)
#
#         pygame.display.flip()
#         CLOCK.tick(FPS)
#
# if __name__ == "__main__":
#     main()
# ```
# This code implements a basic version of the classic Ping Pong game using Pygame. It includes a ball that bounces around the screen, two paddles that can be controlled by the player, and a scoring system. The game can be played by two players using the W and S keys for the left paddle and the UP and DOWN keys for the right paddle.
